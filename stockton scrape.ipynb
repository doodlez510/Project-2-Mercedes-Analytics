# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd
from requests import get
import itertools
import matplotlib.pyplot as plt
from time import sleep
from random import randint

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.mbofstockton.com/used-vehicles/'
browser.visit(url)

# %%
html=browser.html

# %%
stockton_soup = bs(html, 'html.parser')

# %%
# stockton_soup.find_all('div',class_="options")

# %%
mylist=[]
options=stockton_soup.find_all('div',class_='options')
for car in options:
#     car_sublist = []
    mydict={}
    for li in car.find_all('li'):
        
        mydict[li.text.split(':')[0]]=li.text.split(':')[1]
        details=car.text
#         print(details, '-'*80)
    mylist.append(mydict)

# %%
mylist2=[{k.replace('\n','').replace('\t',''): v.replace('\n','').replace('\t','') for k,v in x.items()} for x in mylist]

# %%
options_df=pd.DataFrame(mylist2)
options_df
# Out:
#    Drivetrain                           Engine                   Exterior  \
# 0         RWD                  Gas V6 2.5L/152                   Charcoal
# 1         RWD                  Gas V6 3.2L/195        Capri Blue Metallic
# 2         4WD          Gas/Ethanol V8 5.3L/325          Tungsten Metallic
# 3         FWD    Regular Unleaded I-4 1.6 L/97                Chalk White
# 4         RWD     Turbocharged Gas I4 1.8L/110               Arctic White
# 5         FWD   Regular Unleaded I-4 1.8 L/110                Super Black
# 6         FWD   Regular Unleaded I-4 2.0 L/122                     Silver
# 7         4WD                  Gas V8 4.4L/268                      White
# 8         FWD    Regular Unleaded I-4 1.6 L/97              Century White
# 9         RWD         Turbocharged I4 2.0L/122   Thunder Gray ChromaFlair
# 10        FWD   Regular Unleaded I-4 2.4 L/144        Crystal Black Pearl
# 11        FWD   Regular Unleaded I-4 1.8 L/110                Super White
# 12        4WD   Regular Unleaded V-6 3.5 L/213                        NaN
# 13        FWD       Gas/Electric I-4 2.0 L/122               Oxford White
# 14        FWD   Regular Unleaded I-4 2.5 L/152           Brilliant Silver
# 15        AWD   Regular Unleaded I-4 2.0 L/122             Magnetic Black
# 16        AWD   Regular Unleaded I-4 2.5 L/152           Brilliant Silver
# 17        4WD   Regular Unleaded V-6 3.5 L/213                      White
# 18        RWD   Regular Unleaded V-6 3.6 L/220          Granite Pearlcoat
# 19        RWD   Regular Unleaded V-6 3.6 L/220                Gloss Black
#
#                                                   HWY  \
# 0    32 MPG                                       ...
# 1    28 MPG                                       ...
# 2    22 MPG                                       ...
# 3    36 MPG                                       ...
# 4    31 MPG                                       ...
# 5    37 MPG                                       ...
# 6    38 MPG                                       ...
# 7    18 MPG                                       ...
# 8    36 MPG                                       ...
# 9    31 MPG                                       ...
# 10   36 MPG                                       ...
# 11   36 MPG                                       ...
# 12   23 MPG                                       ...
# 13   41 MPG                                       ...
# 14   38 MPG                                       ...
# 15   30 MPG                                       ...
# 16   32 MPG                                       ...
# 17   23 MPG                                       ...
# 18   30 MPG                                       ...
# 19   30 MPG                                       ...
#
#                                Interior   Mileage  \
# 0                                   NaN   157,858
# 1                                   NaN    74,456
# 2                             Jet Black   172,207
# 3                                 Beige    24,026
# 4                         Almond MB-Tex   136,268
# 5                              Charcoal    23,821
# 6                                 Black    33,316
# 7                                   NaN    74,803
# 8                                 Black    26,898
# 9    Light Platinum w/Jet Black Accents    89,244
# 10                                  NaN    74,636
# 11                                  Ash    38,364
# 12                                  NaN   137,431
# 13                                Ebony    33,558
# 14                             Charcoal    22,025
# 15                             Charcoal    24,991
# 16                             Charcoal    36,398
# 17                                  NaN   103,135
# 18                                Black    27,961
# 19                                Black    38,623
#
#                               Trans
# 0                 6-Speed Automatic
# 1            5-Speed Automatic w/OD
# 2                 6-Speed Automatic
# 3            6-Speed Automatic w/OD
# 4                 7-Speed Automatic
# 5                  1-Speed CVT w/OD
# 6    6-Speed Auto-Shift Manual w/OD
# 7            6-Speed Automatic w/OD
# 8    6-Speed Auto-Shift Manual w/OD
# 9                 6-Speed Automatic
# 10                 1-Speed CVT w/OD
# 11                 1-Speed CVT w/OD
# 12           6-Speed Automatic w/OD
# 13                 1-Speed CVT w/OD
# 14                 1-Speed CVT w/OD
# 15                 1-Speed CVT w/OD
# 16                 1-Speed CVT w/OD
# 17           6-Speed Automatic w/OD
# 18           8-Speed Automatic w/OD
# 19           8-Speed Automatic w/OD

# %%
first_car=stockton_soup.find('div',class_='vehicle-overview')

# %%
vin_num=first_car.span.text
vin_num.split(':')[1]
# Out:
# ' JTHBK262X75028035'

# %%
org_first_car_price=first_car.find('div',class_='price-block our-price real-price')
org_first_car_price.find('span',class_='price').text
# Out:
# '$8,900'

# %%
stock=first_car.find('span',class_='stock-label').text
stock=stock.split(':')[1]
stock
# Out:
# ' P3392A'

# %%
headers = {"Accept-Language": "en-US, en;q=0.5"}
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
import pandas as pd
from urllib.request import urlopen
prices=[]
vins=[]
stocks=[]
titles=[]
start_time = time()
requests = 0
pages = [str(i) for i in range(1,5)]

for page in pages:
    
#     response = get(f'https://www.mbofstockton.com/used-vehicles/#action=im_ajax_call&perform=get_results&page={page}',headers = headers)
    
    response = get(f'https://www.mbofstockton.com/used-vehicles/#action=im_ajax_call&perform=get_results&page=2',headers = headers)
    
    
    sleep(randint(8,15))
    requests += 1
    elapsed_time = time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
#     clear_output(wait = True)
     
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(requests, response.status_code))
    if requests > 72:
        warn('Number of requests was greater than expected.')
        break
    stockton_soup = bs(response.text, 'html.parser')
    print(response.text)
    cars=stockton_soup.find_all('div',class_='vehicle-overview')

    for car in cars:
        stock=car.find('span',class_='stock-label').text
        stock=stock.split(':')[1]
        stocks.append(stock)

        vin=car.span.text
        vin=vin.split(':')[1]
        vins.append(vin)

        price=car.find('div',class_='price-block our-price real-price').find('span',class_='price').text
        prices.append(price)
        prices=[x.replace('\n','').replace('\t','') for x in prices]
        
        title=car.find('a').text
        titles.append(title)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-2c6592af19ef> in <module>
#       9 stocks=[]
#      10 titles=[]
# ---> 11 start_time = time()
#      12 requests = 0
#      13 pages = [str(i) for i in range(1,5)]
#
# NameError: name 'time' is not defined

# %%
titles

# %%
browser.click_link_by_text

# %%
titles

# %%
stockton_df=pd.DataFrame({'Stock #': stocks,
'Original Price': prices,
'Vin #': vins,
})
stockton_df

# %%
pd.merge(stockton_df,options_df,left_index=True,right_index=True)

# %%
import codecs
f=codecs.open("Stockton_website_1.html", 'r','utf-8').read()
# print (f.read())

# %%
stockton_soup_1= bs(f,'html.parser')

# %%
mylist=[]
options=stockton_soup_1.find_all('div',class_='options')
for car in options:
#     car_sublist = []
    mydict={}
    for li in car.find_all('li'):
        
        mydict[li.text.split(':')[0]]=li.text.split(':')[1]
        details=car.text
#         print(details, '-'*80)
    mylist.append(mydict)

# %%
mylist2=[{k.replace('\n','').replace('\t',''): v.replace('\n','').replace('\t','') for k,v in x.items()} for x in mylist]

# %%
options_df=pd.DataFrame(mylist2)
options_df.head()
# Out:
#   Drivetrain                           Engine              Exterior  \
# 0        RWD                  Gas V6 2.5L/152              Charcoal
# 1        RWD                  Gas V6 3.2L/195   Capri Blue Metallic
# 2        FWD    Regular Unleaded I-4 1.6 L/97           Chalk White
# 3        RWD     Turbocharged Gas I4 1.8L/110          Arctic White
# 4        FWD   Regular Unleaded I-4 1.8 L/110           Super Black
#
#                                                  HWY        Interior  \
# 0   32 MPG                                       ...             NaN
# 1   28 MPG                                       ...             NaN
# 2   36 MPG                                       ...           Beige
# 3   31 MPG                                       ...   Almond MB-Tex
# 4   37 MPG                                       ...        Charcoal
#
#     Mileage                    Trans
# 0   157,858        6-Speed Automatic
# 1    74,456   5-Speed Automatic w/OD
# 2    24,026   6-Speed Automatic w/OD
# 3   136,268        7-Speed Automatic
# 4    23,821         1-Speed CVT w/OD

# %%
cars=stockton_soup_1.find_all('div',class_='vehicle-overview')

# %%
stocks=[]
prices=[]
vins=[]
sale_prices=[]
titles=[]
years=[]

cars=stockton_soup.find_all('div',class_='vehicle-overview')

for car in cars:
    stock=car.find('span',class_='stock-label').text
    stock=stock.split(':')[1]
    stocks.append(stock)

    vin=car.span.text
    vin=vin.split(':')[1]
    vins.append(vin)

    price=car.find('div',class_='price-block our-price real-price').find('span',class_='price').text
    prices.append(price)
    prices=[x.replace('\n','').replace('\t','') for x in prices]
        
    year=car.find('a').text
    if year.split(" ")[0] == "Certified":
        year=year.split(" ")[2]
        years.append(year)
    else:
        year=year.split(" ")[1]
        years.append(year)
        
    title=car.find('a').text
    if title.split(' ',2)[0]=='Pre-Owned':
        title=title.split(' ',2)[2]
        titles.append(title)
    else:
        title=title.split(' ',3)[3]
        titles.append(title)

# %%
stockton_df_1=pd.DataFrame({'Stock #': stocks,
'Original Price': prices,
'Vin #': vins,
'Vehicle Name':titles,
'Year':years
})
stockton_df_1
# Out:
#     Stock # Original Price               Vin #  \
# 0    P3392A         $8,900   JTHBK262X75028035
# 1    L5328A         $9,999   WDBUF65J85A693548
# 2    P3423A        $11,040   1GCVKREC5EZ410142
# 3     P3440        $11,988   KMHCT4AE5HU362511
# 4    P3349A        $11,995   WDDGF4HB6CA728789
# 5     P3410        $12,988   3N1AB7AP2HL710117
# 6     P3420        $12,988   1FADP3K26JL324170
# 7     5793A        $12,995   SALSF25469A213372
# 8     P3289        $13,488   KMHTC6AD2GU257832
# 9    P3276A        $13,988   1G6AE5SXXD0137372
# 10   P3391A        $14,040   1HGCR2F80FA156555
# 11    P3437        $14,788   2T1BURHE6JC989284
# 12    5759A        $14,988   1FM5K8F84EGA13808
# 13    P3429        $14,988   3FA6P0LU8HR232707
# 14    p3441        $15,988   1N4AL3AP7JC111627
# 15    P3404        $17,988   JN1BJ1CR5JW264130
# 16    P3436        $17,988   KNMAT2MV7JP568882
# 17    5821A        $18,999   1FM5K8F88EGC13235
# 18    P3398        $21,988   2C3CDZAG1JH237647
# 19   P3444A        $21,999   2C3CCABGXHH612593
#
#                                          Vehicle Name  Year
# 0                                    Lexus IS 250 250  2007
# 1                          Mercedes-Benz E-Class 3.2L  2005
# 2                     Chevrolet Silverado 1500 LT 4WD  2014
# 3                                   Hyundai Accent SE  2017
# 4                 Mercedes-Benz C 250 With Navigation  2012
# 5                                    Nissan Sentra SV  2017
# 6                                       Ford Focus SE  2018
# 7   Land Rover Range Rover Sport HSE With Navigati...  2009
# 8                                    Hyundai Veloster  2016
# 9                Cadillac ATS Premium With Navigation  2013
# 10                            Honda Accord Sedan EX-L  2015
# 11                                  Toyota Corolla LE  2018
# 12                          Ford Explorer Limited 4WD  2014
# 13                              Ford Fusion Hybrid SE  2017
# 14                               Nissan Altima 2.5 SV  2018
# 15                           Nissan Rogue Sport S AWD  2018
# 16                                Nissan Rogue SV AWD  2018
# 17                          Ford Explorer Limited 4WD  2014
# 18                               Dodge Challenger SXT  2018
# 19                                  Chrysler 300 300S  2017

# %%
stockton_df_1=pd.merge(stockton_df_1,options_df,left_index=True,right_index=True)
stockton_df_1.head()
# Out:
#    Stock # Original Price               Vin #  \
# 0   P3392A         $8,900   JTHBK262X75028035
# 1   L5328A         $9,999   WDBUF65J85A693548
# 2   P3423A        $11,040   1GCVKREC5EZ410142
# 3    P3440        $11,988   KMHCT4AE5HU362511
# 4   P3349A        $11,995   WDDGF4HB6CA728789
#
#                           Vehicle Name  Year Drivetrain  \
# 0                     Lexus IS 250 250  2007        RWD
# 1           Mercedes-Benz E-Class 3.2L  2005        RWD
# 2      Chevrolet Silverado 1500 LT 4WD  2014        FWD
# 3                    Hyundai Accent SE  2017        RWD
# 4  Mercedes-Benz C 250 With Navigation  2012        FWD
#
#                             Engine              Exterior  \
# 0                  Gas V6 2.5L/152              Charcoal
# 1                  Gas V6 3.2L/195   Capri Blue Metallic
# 2    Regular Unleaded I-4 1.6 L/97           Chalk White
# 3     Turbocharged Gas I4 1.8L/110          Arctic White
# 4   Regular Unleaded I-4 1.8 L/110           Super Black
#
#                                                  HWY        Interior  \
# 0   32 MPG                                       ...             NaN
# 1   28 MPG                                       ...             NaN
# 2   36 MPG                                       ...           Beige
# 3   31 MPG                                       ...   Almond MB-Tex
# 4   37 MPG                                       ...        Charcoal
#
#     Mileage                    Trans
# 0   157,858        6-Speed Automatic
# 1    74,456   5-Speed Automatic w/OD
# 2    24,026   6-Speed Automatic w/OD
# 3   136,268        7-Speed Automatic
# 4    23,821         1-Speed CVT w/OD

# %%
import codecs
f=codecs.open("Stockton_website_2.html", 'r','utf-8').read()
# print (f.read())

# %%
stockton_soup_2 = bs(f,'html.parser')

# %%
mylist=[]
options=stockton_soup_2.find_all('div',class_='options')
for car in options:
#     car_sublist = []
    mydict={}
    for li in car.find_all('li'):
        
        mydict[li.text.split(':')[0]]=li.text.split(':')[1]
        details=car.text
#         print(details, '-'*80)
    mylist.append(mydict)

# %%
mylist2=[{k.replace('\n','').replace('\t',''): v.replace('\n','').replace('\t','') for k,v in x.items()} for x in mylist]

# %%
options_df=pd.DataFrame(mylist2)
options_df.head()
# Out:
#     Drivetrain                                             Engine  \
# 0          FWD                     Regular Unleaded I-4 2.5 L/152
# 1   AWD 4MATIC   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 2          4WD                     Regular Unleaded V-6 3.2 L/198
# 3          4WD                     Regular Unleaded I-4 2.4 L/144
# 4   AWD 4MATIC   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                               Exterior  \
# 0                Sonic Silver Metallic
# 1                         Cirrus White
# 2   Granite Crystal Metallic Clearcoat
# 3               Bright White Clearcoat
# 4                         Cirrus White
#
#                                                  HWY       Interior  Mileage  \
# 0   31 MPG                                       ...          Black   33,748
# 1   32 MPG                                       ...   Beige MB-Tex   48,200
# 2   27 MPG                                       ...          Black   28,221
# 3   25 MPG                                       ...          Black   34,195
# 4   31 MPG                                       ...   Black MB-Tex   31,502
#
#                              Trans
# 0           6-Speed Automatic w/OD
# 1   7-Speed Auto-Shift Manual w/OD
# 2           9-Speed Automatic w/OD
# 3           9-Speed Automatic w/OD
# 4   7-Speed Auto-Shift Manual w/OD

# %%
cars=stockton_soup_2.find_all('div',class_='vehicle-overview')

# %%
stocks=[]
prices=[]
vins=[]
sale_prices=[]
titles=[]
years=[]

for car in cars:
    stock=car.find('span',class_='stock-label').text
    stock=stock.split(':')[1]
    stocks.append(stock)

    vin=car.span.text
    vin=vin.split(':')[1]
    vins.append(vin)

    price=car.find('div',class_='price-block our-price real-price').find('span',class_='price').text
    prices.append(price)
    prices=[x.replace('\n','').replace('\t','') for x in prices]
        
    year=car.find('a').text
    if year.split(" ")[0] == "Certified":
        year=year.split(" ")[2]
        years.append(year)
    else:
        year=year.split(" ")[1]
        years.append(year)
        
    title=car.find('a').text
    if title.split(' ',2)[0]=='Pre-Owned':
        title=title.split(' ',2)[2]
        titles.append(title)
    else:
        title=title.split(' ',3)[3]
        titles.append(title)

# %%
stockton_df_2=pd.DataFrame({'Stock #': stocks,
'Original Price': prices,
'Vin #': vins,
'Vehicle Name':titles,
'Year':years
})
stockton_df_2
# Out:
#     Stock # Original Price               Vin #  \
# 0     P3430        $23,988   JM3KFADM2J0325641
# 1     P3342        $23,988   WDCTG4GB2GJ192298
# 2     P3409        $24,988   1C4PJMDX0KD216632
# 3     P3457        $24,988   1C4PJMBBXJD569174
# 4     P3428        $25,988   WDCTG4GB7HJ323842
# 5     P3425        $25,988   1C4PJMBX9KD313718
# 6     P3445        $25,999   2G61M5S35J9158499
# 7    P3499A        $26,988   1FA6P8CF0G5336884
# 8     5854a        $26,988   JM3KFBDL2H0106122
# 9     P3431        $27,988   5N1DR2MM7JC611400
# 10    P3456        $27,999   1C4PJMDX3KD346775
# 11    P3382        $28,988   1C6RR7TTXKS510818
# 12    P3435        $28,988   1C4HJWDGXHL754270
# 13    P3424        $29,988   4JGDA5GB3FA578658
# 14    P3375        $29,999   WDC0G4KBXGF007976
# 15    P3413        $30,988   1C4HJWEG7HL754239
# 16    P3453        $31,988   1FTEW1EB9JKE47985
# 17    P3359        $31,988   WDC0G4KB8GF024999
# 18    P3432        $31,988   4JGDA5HBXGA770224
# 19    P3386        $31,999   1C4RDJDG5KC559778
#
#                                       Vehicle Name  Year
# 0         Mazda CX-5 Grand Touring With Navigation  2018
# 1                Mercedes-Benz GLA 250 AWD 4MATIC®  2016
# 2                        Jeep Cherokee Limited 4WD  2019
# 3                      Jeep Cherokee Trailhawk 4WD  2018
# 4                Mercedes-Benz GLA 250 AWD 4MATIC®  2017
# 5                      Jeep Cherokee Trailhawk 4WD  2019
# 6                              Cadillac XTS Luxury  2018
# 7                                  Ford Mustang GT  2016
# 8   Mazda CX-5 Grand Touring With Navigation & AWD  2017
# 9                         Nissan Pathfinder SL 4WD  2018
# 10                       Jeep Cherokee Limited 4WD  2019
# 11                        Ram 1500 Classic SLT 4WD  2019
# 12               Jeep Wrangler Unlimited Sport 4WD  2017
# 13        Mercedes-Benz M-Class ML 400 AWD 4MATIC®  2015
# 14               Mercedes-Benz GLC 300 AWD 4MATIC®  2016
# 15              Jeep Wrangler Unlimited Sahara 4WD  2017
# 16                              Ford F-150 XLT 4WD  2018
# 17               Mercedes-Benz GLC 300 AWD 4MATIC®  2016
# 18               Mercedes-Benz GLE 350 AWD 4MATIC®  2016
# 19                       Dodge Durango GT Plus AWD  2019

# %%
stockton_df_2=pd.merge(stockton_df_2,options_df,left_index=True,right_index=True)
stockton_df_2
# Out:
#     Stock # Original Price               Vin #  \
# 0     P3430        $23,988   JM3KFADM2J0325641
# 1     P3342        $23,988   WDCTG4GB2GJ192298
# 2     P3409        $24,988   1C4PJMDX0KD216632
# 3     P3457        $24,988   1C4PJMBBXJD569174
# 4     P3428        $25,988   WDCTG4GB7HJ323842
# 5     P3425        $25,988   1C4PJMBX9KD313718
# 6     P3445        $25,999   2G61M5S35J9158499
# 7    P3499A        $26,988   1FA6P8CF0G5336884
# 8     5854a        $26,988   JM3KFBDL2H0106122
# 9     P3431        $27,988   5N1DR2MM7JC611400
# 10    P3456        $27,999   1C4PJMDX3KD346775
# 11    P3382        $28,988   1C6RR7TTXKS510818
# 12    P3435        $28,988   1C4HJWDGXHL754270
# 13    P3424        $29,988   4JGDA5GB3FA578658
# 14    P3375        $29,999   WDC0G4KBXGF007976
# 15    P3413        $30,988   1C4HJWEG7HL754239
# 16    P3453        $31,988   1FTEW1EB9JKE47985
# 17    P3359        $31,988   WDC0G4KB8GF024999
# 18    P3432        $31,988   4JGDA5HBXGA770224
# 19    P3386        $31,999   1C4RDJDG5KC559778
#
#                                       Vehicle Name  Year   Drivetrain  \
# 0         Mazda CX-5 Grand Touring With Navigation  2018          FWD
# 1                Mercedes-Benz GLA 250 AWD 4MATIC®  2016   AWD 4MATIC
# 2                        Jeep Cherokee Limited 4WD  2019          4WD
# 3                      Jeep Cherokee Trailhawk 4WD  2018          4WD
# 4                Mercedes-Benz GLA 250 AWD 4MATIC®  2017   AWD 4MATIC
# 5                      Jeep Cherokee Trailhawk 4WD  2019          4WD
# 6                              Cadillac XTS Luxury  2018          FWD
# 7                                  Ford Mustang GT  2016          RWD
# 8   Mazda CX-5 Grand Touring With Navigation & AWD  2017          AWD
# 9                         Nissan Pathfinder SL 4WD  2018          4WD
# 10                       Jeep Cherokee Limited 4WD  2019          4WD
# 11                        Ram 1500 Classic SLT 4WD  2019          4WD
# 12               Jeep Wrangler Unlimited Sport 4WD  2017          4WD
# 13        Mercedes-Benz M-Class ML 400 AWD 4MATIC®  2015   AWD 4MATIC
# 14               Mercedes-Benz GLC 300 AWD 4MATIC®  2016   AWD 4MATIC
# 15              Jeep Wrangler Unlimited Sahara 4WD  2017          4WD
# 16                              Ford F-150 XLT 4WD  2018          4WD
# 17               Mercedes-Benz GLC 300 AWD 4MATIC®  2016   AWD 4MATIC
# 18               Mercedes-Benz GLE 350 AWD 4MATIC®  2016   AWD 4MATIC
# 19                       Dodge Durango GT Plus AWD  2019          AWD
#
#                                                Engine  \
# 0                      Regular Unleaded I-4 2.5 L/152
# 1    Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 2                      Regular Unleaded V-6 3.2 L/198
# 3                      Regular Unleaded I-4 2.4 L/144
# 4    Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 5                      Regular Unleaded V-6 3.2 L/198
# 6                                     Gas V6 3.6L/217
# 7                      Premium Unleaded V-8 5.0 L/302
# 8                      Regular Unleaded I-4 2.5 L/152
# 9                      Regular Unleaded V-6 3.5 L/213
# 10                     Regular Unleaded V-6 3.2 L/198
# 11                     Regular Unleaded V-8 5.7 L/345
# 12                     Regular Unleaded V-6 3.6 L/220
# 13          Twin Turbo Premium Unleaded V-6 3.0 L/183
# 14   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 15                     Regular Unleaded V-6 3.6 L/220
# 16                         Regular Unleaded V-6 3.3 L
# 17   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 18                     Premium Unleaded V-6 3.5 L/213
# 19                     Regular Unleaded V-6 3.6 L/220
#
#                                Exterior  \
# 0                 Sonic Silver Metallic
# 1                          Cirrus White
# 2    Granite Crystal Metallic Clearcoat
# 3                Bright White Clearcoat
# 4                          Cirrus White
# 5       Diamond Black Crystal Pearlcoat
# 6                Stellar Black Metallic
# 7                          Shadow Black
# 8                 Machine Gray Metallic
# 9                          Gun Metallic
# 10               Bright White Clearcoat
# 11               Bright White Clearcoat
# 12               Bright White Clearcoat
# 13                                Black
# 14                                Black
# 15               Bright White Clearcoat
# 16                                  NaN
# 17                          Polar White
# 18                                Black
# 19                   DB Black Clearcoat
#
#                                                   HWY            Interior  \
# 0    31 MPG                                       ...               Black
# 1    32 MPG                                       ...        Beige MB-Tex
# 2    27 MPG                                       ...               Black
# 3    25 MPG                                       ...               Black
# 4    31 MPG                                       ...        Black MB-Tex
# 5    24 MPG                                       ...               Black
# 6    28 MPG                                       ...           Jet Black
# 7    25 MPG                                       ...               Ebony
# 8    29 MPG                                       ...               Black
# 9    26 MPG                                       ...            Charcoal
# 10   27 MPG                                       ...               Black
# 11   21 MPG                                       ...   Diesel Gray/Black
# 12   20 MPG                                       ...               Black
# 13   22 MPG                                       ...       Black Leather
# 14   28 MPG                                       ...   Silk Beige MB-Tex
# 15   20 MPG                                       ...               Black
# 16   23 MPG                                       ...                 NaN
# 17   28 MPG                                       ...   Silk Beige MB-Tex
# 18   22 MPG                                       ...        Black MB-Tex
# 19   25 MPG                                       ...               Black
#
#     Mileage                              Trans
# 0    33,748             6-Speed Automatic w/OD
# 1    48,200     7-Speed Auto-Shift Manual w/OD
# 2    28,221             9-Speed Automatic w/OD
# 3    34,195             9-Speed Automatic w/OD
# 4    31,502     7-Speed Auto-Shift Manual w/OD
# 5    13,995             9-Speed Automatic w/OD
# 6    38,611   6-Speed Automatic w/Manual Shift
# 7    27,933             6-Speed Automatic w/OD
# 8    15,444             6-Speed Automatic w/OD
# 9    28,524                   1-Speed CVT w/OD
# 10   12,587             9-Speed Automatic w/OD
# 11   17,249             8-Speed Automatic w/OD
# 12   41,035             5-Speed Automatic w/OD
# 13   39,996             7-Speed Automatic w/OD
# 14   28,094             9-Speed Automatic w/OD
# 15   24,432             5-Speed Automatic w/OD
# 16   24,998             6-Speed Automatic w/OD
# 17   29,540             9-Speed Automatic w/OD
# 18   59,034             7-Speed Automatic w/OD
# 19   12,860             8-Speed Automatic w/OD

# %%
import codecs
f=codecs.open("Stockton_website_3.html", 'r','utf-8').read()
# print (f.read())

# %%
stockton_soup_3 = bs(f,'html.parser')

# %%
mylist=[]
options=stockton_soup_3.find_all('div',class_='options')
for car in options:
#     car_sublist = []
    mydict={}
    for li in car.find_all('li'):
        
        mydict[li.text.split(':')[0]]=li.text.split(':')[1]
        details=car.text
#         print(details, '-'*80)
    mylist.append(mydict)

# %%
mylist2=[{k.replace('\n','').replace('\t',''): v.replace('\n','').replace('\t','') for k,v in x.items()} for x in mylist]

# %%
options_df=pd.DataFrame(mylist2)
options_df.head()
# Out:
#     Drivetrain                                             Engine  \
# 0          4WD                     Regular Unleaded V-8 5.7 L/345
# 1          4WD          Twin Turbo Regular Unleaded V-6 3.5 L/213
# 2   AWD 4MATIC   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3          RWD   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 4          RWD                     Premium Unleaded V-6 3.5 L/213
#
#                             Exterior  \
# 0   Billet Silver Metallic Clearcoat
# 1              Ingot Silver Metallic
# 2                        Polar White
# 3                              White
# 4                                NaN
#
#                                                  HWY            Interior  \
# 0   21 MPG                                       ...               Black
# 1   23 MPG                                       ...   Medium Earth Gray
# 2   28 MPG                                       ...        Black MB-Tex
# 3   30 MPG                                       ...                 NaN
# 4   24 MPG                                       ...                 NaN
#
#    Mileage                    Trans
# 0   24,283   8-Speed Automatic w/OD
# 1   18,677                      NaN
# 2   22,395   9-Speed Automatic w/OD
# 3   45,051   9-Speed Automatic w/OD
# 4   27,888   7-Speed Automatic w/OD

# %%
cars=stockton_soup_3.find_all('div',class_='vehicle-overview')

# %%
stocks=[]
prices=[]
vins=[]
sale_prices=[]
titles=[]
years=[]

for car in cars:
    stock=car.find('span',class_='stock-label').text
    stock=stock.split(':')[1]
    stocks.append(stock)

    vin=car.span.text
    vin=vin.split(':')[1]
    vins.append(vin)

    price=car.find('div',class_='price-block our-price real-price').find('span',class_='price').text
    prices.append(price)
    prices=[x.replace('\n','').replace('\t','') for x in prices]
        
    year=car.find('a').text
    if year.split(" ")[0] == "Certified":
        year=year.split(" ")[2]
        years.append(year)
    else:
        year=year.split(" ")[1]
        years.append(year)
        
    title=car.find('a').text
    if title.split(' ',2)[0]=='Pre-Owned':
        title=title.split(' ',2)[2]
        titles.append(title)
    else:
        title=title.split(' ',3)[3]
        titles.append(title)

# %%
stockton_df_3=pd.DataFrame({'Stock #': stocks,
'Original Price': prices,
'Vin #': vins,
'Vehicle Name':titles,
'Year':years
})
stockton_df_3
# Out:
#    Stock # Original Price               Vin #  \
# 0    P3401        $32,988   1C6SRFBT4KN667627
# 1    P3427        $32,988   1FTEW1EG3JKE48321
# 2    P3443        $34,488   WDC0G4KB2HF123075
# 3    5568A        $34,988   WDDZF4JB3HA028724
# 4    P3459        $35,988   4JGDA5JB9GA790135
# 5    P3417        $36,988   1GYKNFRS0KZ130547
# 6    P3418        $37,988   JN8AY2NC4KX509731
# 7    P3458        $37,999   4JGDA5HB1GA724944
# 8    L5003        $38,499   55SWF4JB0JU271349
# 9    5710A        $39,988   WDDZF4JB0JA342143
# 10   P3454        $39,999   1GNSKHKC2JR334737
# 11   P3360        $39,999   WDC0G4KB3JV036510
# 12   P3438        $41,988   WDC0J4KB3HF189782
# 13   P3402        $42,988   1GNSKBKC7KR121703
# 14   L5335        $43,995   55SWF8DB4KU285193
# 15   L5473        $44,375   55SWF8DB5KU298714
# 16   P3455        $44,988   1FT7W2BT6JEB91007
# 17   L5260        $46,835   WDC0G4JB0KV122800
# 18   P3315        $53,988   WDDJK6FA4GF039835
# 19   L5366        $60,555   WDDZF4JB3KA552267
#
#                               Vehicle Name  Year
# 0          Ram 1500 Big Horn/Lone Star 4WD  2019
# 1                       Ford F-150 XLT 4WD  2018
# 2        Mercedes-Benz GLC 300 AWD 4MATIC®  2017
# 3                      Mercedes-Benz E 300  2017
# 4                    Mercedes-Benz GLE 350  2016
# 5      Cadillac XT5 Premium Luxury AWD AWD  2019
# 6   Nissan Armada SL With Navigation & AWD  2019
# 7        Mercedes-Benz GLE 350 AWD 4MATIC®  2016
# 8                      Mercedes-Benz C 300  2018
# 9                      Mercedes-Benz E 300  2018
# 10               Chevrolet Suburban LT 4WD  2018
# 11       Mercedes-Benz GLC 300 AWD 4MATIC®  2018
# 12       Mercedes-Benz GLC 300 AWD 4MATIC®  2017
# 13                  Chevrolet Tahoe LT 4WD  2019
# 14                     Mercedes-Benz C 300  2019
# 15                     Mercedes-Benz C 300  2019
# 16       Ford Super Duty F-250 SRW XLT 4WD  2018
# 17                   Mercedes-Benz GLC 300  2019
# 18                    Mercedes-Benz SL 400  2016
# 19                     Mercedes-Benz E 300  2019

# %%
stockton_df_3=pd.merge(stockton_df_3,options_df,left_index=True,right_index=True)
stockton_df_3
# Out:
#    Stock # Original Price               Vin #  \
# 0    P3401        $32,988   1C6SRFBT4KN667627
# 1    P3427        $32,988   1FTEW1EG3JKE48321
# 2    P3443        $34,488   WDC0G4KB2HF123075
# 3    5568A        $34,988   WDDZF4JB3HA028724
# 4    P3459        $35,988   4JGDA5JB9GA790135
# 5    P3417        $36,988   1GYKNFRS0KZ130547
# 6    P3418        $37,988   JN8AY2NC4KX509731
# 7    P3458        $37,999   4JGDA5HB1GA724944
# 8    L5003        $38,499   55SWF4JB0JU271349
# 9    5710A        $39,988   WDDZF4JB0JA342143
# 10   P3454        $39,999   1GNSKHKC2JR334737
# 11   P3360        $39,999   WDC0G4KB3JV036510
# 12   P3438        $41,988   WDC0J4KB3HF189782
# 13   P3402        $42,988   1GNSKBKC7KR121703
# 14   L5335        $43,995   55SWF8DB4KU285193
# 15   L5473        $44,375   55SWF8DB5KU298714
# 16   P3455        $44,988   1FT7W2BT6JEB91007
# 17   L5260        $46,835   WDC0G4JB0KV122800
# 18   P3315        $53,988   WDDJK6FA4GF039835
# 19   L5366        $60,555   WDDZF4JB3KA552267
#
#                               Vehicle Name  Year   Drivetrain  \
# 0          Ram 1500 Big Horn/Lone Star 4WD  2019          4WD
# 1                       Ford F-150 XLT 4WD  2018          4WD
# 2        Mercedes-Benz GLC 300 AWD 4MATIC®  2017   AWD 4MATIC
# 3                      Mercedes-Benz E 300  2017          RWD
# 4                    Mercedes-Benz GLE 350  2016          RWD
# 5      Cadillac XT5 Premium Luxury AWD AWD  2019          AWD
# 6   Nissan Armada SL With Navigation & AWD  2019          AWD
# 7        Mercedes-Benz GLE 350 AWD 4MATIC®  2016   AWD 4MATIC
# 8                      Mercedes-Benz C 300  2018          RWD
# 9                      Mercedes-Benz E 300  2018          RWD
# 10               Chevrolet Suburban LT 4WD  2018          4WD
# 11       Mercedes-Benz GLC 300 AWD 4MATIC®  2018   AWD 4MATIC
# 12       Mercedes-Benz GLC 300 AWD 4MATIC®  2017   AWD 4MATIC
# 13                  Chevrolet Tahoe LT 4WD  2019          4WD
# 14                     Mercedes-Benz C 300  2019          RWD
# 15                     Mercedes-Benz C 300  2019          RWD
# 16       Ford Super Duty F-250 SRW XLT 4WD  2018          4WD
# 17                   Mercedes-Benz GLC 300  2019          RWD
# 18                    Mercedes-Benz SL 400  2016          RWD
# 19                     Mercedes-Benz E 300  2019          RWD
#
#                                                Engine  \
# 0                      Regular Unleaded V-8 5.7 L/345
# 1           Twin Turbo Regular Unleaded V-6 3.5 L/213
# 2    Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3    Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 4                      Premium Unleaded V-6 3.5 L/213
# 5                                     Gas V6 3.6L/222
# 6                      Regular Unleaded V-8 5.6 L/339
# 7                      Premium Unleaded V-6 3.5 L/213
# 8    Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 9    Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 10                               Gas/Ethanol V8 5.3L/
# 11   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 12   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 13                               Gas/Ethanol V8 5.3L/
# 14   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 15   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 16             Intercooled Turbo Diesel V-8 6.7 L/406
# 17   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 18          Twin Turbo Premium Unleaded V-6 3.0 L/183
# 19   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                              Exterior  \
# 0    Billet Silver Metallic Clearcoat
# 1               Ingot Silver Metallic
# 2                         Polar White
# 3                               White
# 4                                 NaN
# 5             Radiant Silver Metallic
# 6                         Super Black
# 7                                 NaN
# 8                 Lunar Blue Metallic
# 9                         Polar White
# 10                              Black
# 11                              Black
# 12                        Polar White
# 13                Silver Ice Metallic
# 14      designo Cardinal Red Metallic
# 15                              Black
# 16              Ingot Silver Metallic
# 17             Mojave Silver Metallic
# 18               designo Cardinal Red
# 19                              Black
#
#                                                   HWY  \
# 0    21 MPG                                       ...
# 1    23 MPG                                       ...
# 2    28 MPG                                       ...
# 3    30 MPG                                       ...
# 4    24 MPG                                       ...
# 5    25 MPG                                       ...
# 6    18 MPG                                       ...
# 7    22 MPG                                       ...
# 8    33 MPG                                       ...
# 9    30 MPG                                       ...
# 10   22 MPG                                       ...
# 11   28 MPG                                       ...
# 12   27 MPG                                       ...
# 13   21 MPG                                       ...
# 14   34 MPG                                       ...
# 15   34 MPG                                       ...
# 16    MPG                                         ...
# 17   27 MPG                                       ...
# 18   27 MPG                                       ...
# 19   30 MPG                                       ...
#
#                             Interior  Mileage                    Trans
# 0                              Black   24,283   8-Speed Automatic w/OD
# 1                  Medium Earth Gray   18,677                      NaN
# 2                       Black MB-Tex   22,395   9-Speed Automatic w/OD
# 3                                NaN   45,051   9-Speed Automatic w/OD
# 4                                NaN   27,888   7-Speed Automatic w/OD
# 5                       Sahara Beige   26,053        8-Speed Automatic
# 6                           Charcoal   22,691   7-Speed Automatic w/OD
# 7                                NaN   21,531   7-Speed Automatic w/OD
# 8                  Silk Beige MB-Tex    7,081   9-Speed Automatic w/OD
# 9                       Black MB-Tex   31,167   9-Speed Automatic w/OD
# 10                         Jet Black   38,892        6-Speed Automatic
# 11                      Black MB-Tex    6,305   9-Speed Automatic w/OD
# 12                      Black MB-Tex   29,640   9-Speed Automatic w/OD
# 13                        Cocoa/Dune   20,366        6-Speed Automatic
# 14                 Silk Beige MB-Tex    7,839   9-Speed Automatic w/OD
# 15                      Black MB-Tex   12,663   9-Speed Automatic w/OD
# 16                             Black   36,022   6-Speed Automatic w/OD
# 17                      Black MB-Tex    7,628   9-Speed Automatic w/OD
# 18   Porcelain / Black Nappa Leather   28,287   7-Speed Automatic w/OD
# 19                      Black MB-Tex        0   9-Speed Automatic w/OD

# %%
stockton_df=pd.concat([stockton_df_1,stockton_df_2,stockton_df_3])
stockton_df.head()
# Out:
#    Stock # Original Price               Vin #  \
# 0   P3392A         $8,900   JTHBK262X75028035
# 1   L5328A         $9,999   WDBUF65J85A693548
# 2   P3423A        $11,040   1GCVKREC5EZ410142
# 3    P3440        $11,988   KMHCT4AE5HU362511
# 4   P3349A        $11,995   WDDGF4HB6CA728789
#
#                           Vehicle Name  Year Drivetrain  \
# 0                     Lexus IS 250 250  2007        RWD
# 1           Mercedes-Benz E-Class 3.2L  2005        RWD
# 2      Chevrolet Silverado 1500 LT 4WD  2014        FWD
# 3                    Hyundai Accent SE  2017        RWD
# 4  Mercedes-Benz C 250 With Navigation  2012        FWD
#
#                             Engine              Exterior  \
# 0                  Gas V6 2.5L/152              Charcoal
# 1                  Gas V6 3.2L/195   Capri Blue Metallic
# 2    Regular Unleaded I-4 1.6 L/97           Chalk White
# 3     Turbocharged Gas I4 1.8L/110          Arctic White
# 4   Regular Unleaded I-4 1.8 L/110           Super Black
#
#                                                  HWY        Interior  \
# 0   32 MPG                                       ...             NaN
# 1   28 MPG                                       ...             NaN
# 2   36 MPG                                       ...           Beige
# 3   31 MPG                                       ...   Almond MB-Tex
# 4   37 MPG                                       ...        Charcoal
#
#     Mileage                    Trans
# 0   157,858        6-Speed Automatic
# 1    74,456   5-Speed Automatic w/OD
# 2    24,026   6-Speed Automatic w/OD
# 3   136,268        7-Speed Automatic
# 4    23,821         1-Speed CVT w/OD

# %%
location=stockton_soup_1.find('h1').text
location=location.split('in ',1)[1]

# %%
stockton_df['Location']=location

# %%
stockton_df.head()
# Out:
#    Stock # Original Price               Vin #  \
# 0   P3392A         $8,900   JTHBK262X75028035
# 1   L5328A         $9,999   WDBUF65J85A693548
# 2   P3423A        $11,040   1GCVKREC5EZ410142
# 3    P3440        $11,988   KMHCT4AE5HU362511
# 4   P3349A        $11,995   WDDGF4HB6CA728789
#
#                           Vehicle Name  Year Drivetrain  \
# 0                     Lexus IS 250 250  2007        RWD
# 1           Mercedes-Benz E-Class 3.2L  2005        RWD
# 2      Chevrolet Silverado 1500 LT 4WD  2014        FWD
# 3                    Hyundai Accent SE  2017        RWD
# 4  Mercedes-Benz C 250 With Navigation  2012        FWD
#
#                             Engine              Exterior  \
# 0                  Gas V6 2.5L/152              Charcoal
# 1                  Gas V6 3.2L/195   Capri Blue Metallic
# 2    Regular Unleaded I-4 1.6 L/97           Chalk White
# 3     Turbocharged Gas I4 1.8L/110          Arctic White
# 4   Regular Unleaded I-4 1.8 L/110           Super Black
#
#                                                  HWY        Interior  \
# 0   32 MPG                                       ...             NaN
# 1   28 MPG                                       ...             NaN
# 2   36 MPG                                       ...           Beige
# 3   31 MPG                                       ...   Almond MB-Tex
# 4   37 MPG                                       ...        Charcoal
#
#     Mileage                    Trans      Location
# 0   157,858        6-Speed Automatic  Stockton, CA
# 1    74,456   5-Speed Automatic w/OD  Stockton, CA
# 2    24,026   6-Speed Automatic w/OD  Stockton, CA
# 3   136,268        7-Speed Automatic  Stockton, CA
# 4    23,821         1-Speed CVT w/OD  Stockton, CA

# %%
stockton_df.to_csv('stockton_df.csv', sep = ',')
