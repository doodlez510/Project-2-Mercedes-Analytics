# %%
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
import pandas as pd

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.mbofedh.com/used-vehicles/'
browser.visit(url)

# %%
html=browser.html

# %%
edh_soup = bs(html, 'html.parser')

# %%
mylist=[]
options=edh_soup.find_all('div',class_='options')
for option in options:
    for li in option.find_all('li'):
            mydict={}
            mydict[li.text.split(':')[0]]=li.text.split(':')[1]
            details=option.text
            mylist.append(mydict)

# %%
mylist2=[{k.replace('\n','').replace('\t',''): v.replace('\n','').replace('\t','') for k,v in x.items()} for x in mylist]
mylist2
pd.DataFrame(mylist2)
# Out:
#              Drivetrain                                             Engine  \
# 0                   NaN   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 1                   NaN                                                NaN
# 2     Front Wheel Drive                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# 5                   NaN                                                NaN
# 6                   NaN                                                NaN
# 7                   NaN   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 8                   NaN                                                NaN
# 9           AWD 4MATIC®                                                NaN
# 10                  NaN                                                NaN
# 11                  NaN                                                NaN
# 12                  NaN                                                NaN
# 13                  NaN                                                NaN
# 14                  NaN   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 15                  NaN                                                NaN
# 16    Front Wheel Drive                                                NaN
# 17                  NaN                                                NaN
# 18                  NaN                                                NaN
# 19                  NaN                                                NaN
# 20                  NaN                                                NaN
# 21                  NaN   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 22                  NaN                                                NaN
# 23          AWD 4MATIC®                                                NaN
# 24                  NaN                                                NaN
# 25                  NaN                                                NaN
# 26                  NaN                                                NaN
# 27                  NaN                                                NaN
# 28                  NaN   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 29                  NaN                                                NaN
# ..                  ...                                                ...
# 108                 NaN                                                NaN
# 109                 NaN                                                NaN
# 110                 NaN                                                NaN
# 111                 NaN       Intercooled Turbo Gas/Electric I-4 2.0 L/121
# 112                 NaN                                                NaN
# 113         AWD 4MATIC®                                                NaN
# 114                 NaN                                                NaN
# 115                 NaN                                                NaN
# 116                 NaN                                                NaN
# 117                 NaN   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 118                 NaN                                                NaN
# 119   Front Wheel Drive                                                NaN
# 120                 NaN                                                NaN
# 121                 NaN                                                NaN
# 122                 NaN                                                NaN
# 123                 NaN                                                NaN
# 124                 NaN          Twin Turbo Premium Unleaded V-6 3.0 L/183
# 125                 NaN                                                NaN
# 126         AWD 4MATIC®                                                NaN
# 127                 NaN                                                NaN
# 128                 NaN                                                NaN
# 129                 NaN                                                NaN
# 130                 NaN                                                NaN
# 131                 NaN   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 132                 NaN                                                NaN
# 133    Rear Wheel Drive                                                NaN
# 134                 NaN                                                NaN
# 135                 NaN                                                NaN
# 136                 NaN                                                NaN
# 137                 NaN                                                NaN
#
#                             Exterior  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                      Mountain Grey
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                       Polar White
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                       Night Black
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24           Brilliant Blue Metallic
# 25                               NaN
# 26                               NaN
# 27                               NaN
# 28                               NaN
# 29                               NaN
# ..                               ...
# 108                              NaN
# 109                              NaN
# 110                              NaN
# 111                              NaN
# 112                              NaN
# 113                              NaN
# 114           Selenite Grey Metallic
# 115                              NaN
# 116                              NaN
# 117                              NaN
# 118                              NaN
# 119                              NaN
# 120                    Mountain Grey
# 121                              NaN
# 122                              NaN
# 123                              NaN
# 124                              NaN
# 125                              NaN
# 126                              NaN
# 127   designo Diamond White Metallic
# 128                              NaN
# 129                              NaN
# 130                              NaN
# 131                              NaN
# 132                              NaN
# 133                              NaN
# 134                      Polar White
# 135                              NaN
# 136                              NaN
# 137                              NaN
#
#                                                    HWY  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6     37 MPG                                       ...
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13    31 MPG                                       ...
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20    37 MPG                                       ...
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27    28 MPG                                       ...
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 108                                                NaN
# 109                                                NaN
# 110   26 MPG                                       ...
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123   38 MPG                                       ...
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130   29 MPG                                       ...
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137   34 MPG                                       ...
#
#                       Interior  Mileage                            Trans
# 0                          NaN      NaN                              NaN
# 1                          NaN      NaN   7-Speed Auto-Shift Manual w/OD
# 2                          NaN      NaN                              NaN
# 3                          NaN      NaN                              NaN
# 4                 Black MB-Tex      NaN                              NaN
# 5                          NaN    9,188                              NaN
# 6                          NaN      NaN                              NaN
# 7                          NaN      NaN                              NaN
# 8                          NaN      NaN   7-Speed Auto-Shift Manual w/OD
# 9                          NaN      NaN                              NaN
# 10                         NaN      NaN                              NaN
# 11                Black MB-Tex      NaN                              NaN
# 12                         NaN    5,814                              NaN
# 13                         NaN      NaN                              NaN
# 14                         NaN      NaN                              NaN
# 15                         NaN      NaN   7-Speed Auto-Shift Manual w/OD
# 16                         NaN      NaN                              NaN
# 17                         NaN      NaN                              NaN
# 18                Black MB-Tex      NaN                              NaN
# 19                         NaN    5,798                              NaN
# 20                         NaN      NaN                              NaN
# 21                         NaN      NaN                              NaN
# 22                         NaN      NaN           9-Speed Automatic w/OD
# 23                         NaN      NaN                              NaN
# 24                         NaN      NaN                              NaN
# 25                Black MB-Tex      NaN                              NaN
# 26                         NaN    4,985                              NaN
# 27                         NaN      NaN                              NaN
# 28                         NaN      NaN                              NaN
# 29                         NaN      NaN           9-Speed Automatic w/OD
# ..                         ...      ...                              ...
# 108                      Black      NaN                              NaN
# 109                        NaN   13,122                              NaN
# 110                        NaN      NaN                              NaN
# 111                        NaN      NaN                              NaN
# 112                        NaN      NaN           7-Speed Automatic w/OD
# 113                        NaN      NaN                              NaN
# 114                        NaN      NaN                              NaN
# 115               Black MB-Tex      NaN                              NaN
# 116                        NaN   31,299                              NaN
# 117                        NaN      NaN                              NaN
# 118                        NaN      NaN   7-Speed Auto-Shift Manual w/OD
# 119                        NaN      NaN                              NaN
# 120                        NaN      NaN                              NaN
# 121   Black MB-Tex w/ DINAMICA      NaN                              NaN
# 122                        NaN   53,671                              NaN
# 123                        NaN      NaN                              NaN
# 124                        NaN      NaN                              NaN
# 125                        NaN      NaN           7-Speed Automatic w/OD
# 126                        NaN      NaN                              NaN
# 127                        NaN      NaN                              NaN
# 128      Cranberry Red Leather      NaN                              NaN
# 129                        NaN   31,588                              NaN
# 130                        NaN      NaN                              NaN
# 131                        NaN      NaN                              NaN
# 132                        NaN      NaN           9-Speed Automatic w/OD
# 133                        NaN      NaN                              NaN
# 134                        NaN      NaN                              NaN
# 135               Black MB-Tex      NaN                              NaN
# 136                        NaN    8,395                              NaN
# 137                        NaN      NaN                              NaN
#
# [138 rows x 7 columns]

# %%
cars=edh_soup.find_all('div',class_='vehicle-overview')

# %%
stocks=[]
prices=[]
vins=[]
sale_prices=[]
titles=[]
years=[]

for car in cars:
    if car.find('div',class_='price-block our-price ') is not None:
        stock=car.find('span',class_='stock-label').text
        stock=stock.split(':')[1]
        stocks.append(stock)

        vin=car.span.text
        vin=vin.split(':')[1]
        vins.append(vin)
        if car.find('div',class_='price-block original') is not None:
            price=car.find('div',class_='price-block original').find('span',class_='price').text
            prices.append(price)
            prices=[x.replace('\n','').replace('\t','') for x in prices]

        sale_price=car.find('div',class_='price-block our-price ').find('span',class_='price').text
        sale_prices.append(sale_price)
        sale_prices=[x.replace('\n','').replace('\t','') for x in sale_prices]
        
        year=car.find('a').text
        if year.split(" ")[0] == "Certified":
            year=year.split(" ")[2]
            years.append(year)
        else:
            year=year.split(" ")[1]
            years.append(year)
        
        title=car.find('a').text
        if title.split(' ',2)[0]=='Pre-Owned':
            title=title.split(' ',2)[2]
            titles.append(title)
        else:
            title=title.split(' ',3)[3]
            titles.append(title)

# %%
edh_df=pd.DataFrame({'Stock #': stocks,
'Original Price': prices,
'Sales Price': sale_prices,
'Vin #': vins,
'Vehicle Name':titles
})
edh_df
# Out:
#     Stock #                 Original Price                     Sales Price  \
# 0    R20899              $38,240                         $32,578
# 1    R20910              $39,395                         $34,298
# 2    R20964              $35,145                         $32,452
# 3    R20979              $47,991                         $41,995
# 4    R20811              $45,175                         $36,892
# 5    R20990              $39,095                         $34,332
# 6    R20988              $45,095                         $38,079
# 7    R20986              $79,520                         $67,922
# 8    R20987              $61,650                         $51,983
# 9    R20992              $33,995                         $26,992
# 10   R21005              $69,995                         $64,322
# 11   R21011              $54,991                         $49,222
# 12   R21024              $35,995                         $31,422
# 13   R21031              $32,995                         $28,992
# 14   R21032              $72,995                         $64,992
# 15   R21035              $49,995                         $45,922
# 16   R21037              $53,945                         $49,622
# 17   R21040              $23,995                         $21,982
# 18   R21038              $44,995                         $41,992
# 19   R21041              $46,575                         $41,995
#
#                  Vin #                                       Vehicle Name
# 0    WDDSJ4EBXKN742067  Pre-Owned 2019 Mercedes-Benz CLA 250 Front Whe...
# 1    WDCTG4GB9KJ551848   Pre-Owned 2019 Mercedes-Benz GLA 250 AWD 4MATIC®
# 2    WDDSJ4EB5KN708246  Pre-Owned 2019 Mercedes-Benz CLA 250 Front Whe...
# 3    WDC0G4KB8JV070443   Pre-Owned 2018 Mercedes-Benz GLC 300 AWD 4MATIC®
# 4    55SWF4JB3JU280062  Pre-Owned 2018 Mercedes-Benz C 300 Rear Wheel ...
# 5    WDDSJ4EB5KN714435  Pre-Owned 2019 Mercedes-Benz CLA 250 Front Whe...
# 6    55SWF8DB9KU286789  Pre-Owned 2019 Mercedes-Benz C 300 Rear Wheel ...
# 7    4JGDF6EE3KB205371   Pre-Owned 2019 Mercedes-Benz GLS 450 AWD 4MATIC®
# 8    4JGDA5GB7KB212111   Pre-Owned 2019 Mercedes-Benz GLE 400 AWD 4MATIC®
# 9    55SWF4HB3GU152726  Certified Pre-Owned 2016 Mercedes-Benz C 350 R...
# 10   WBA6D6C54GGK18191  Pre-Owned 2016 BMW 6 Series ALPINA B6 G/CP AWD...
# 11   WDDLJ7DB3GA164982  Certified Pre-Owned 2016 Mercedes-Benz CLS 550...
# 12   JTHBW1GG7H2138004                Pre-Owned 2017 Lexus ES ES 300h FWD
# 13   WDDSJ4EB7JN536137  Certified Pre-Owned 2018 Mercedes-Benz CLA 250...
# 14   5UXCR6C52KLL05903            Pre-Owned 2019 BMW X5 xDrive40i AWD AWD
# 15   5J8YD4H89JL024615     Pre-Owned 2018 Acura MDX w/Advance Pkg AWD AWD
# 16   WDC0G5EB7JF406286  Certified Pre-Owned 2018 Mercedes-Benz GLC 350...
# 17   WDDSJ4EB1EN120932  Certified Pre-Owned 2014 Mercedes-Benz CLA 250...
# 18   55SWF6EB9GU120542  Certified Pre-Owned 2016 Mercedes-Benz C 450 A...
# 19   55SWF8DBXKU295565  Pre-Owned 2019 Mercedes-Benz C 300 Rear Wheel ...

# %%
mylist=[]
options=edh_soup.find_all('div',class_='options')
for car in options:
#     car_sublist = []
    mydict={}
    for li in car.find_all('li'):
        
        mydict[li.text.split(':')[0]]=li.text.split(':')[1]
        details=car.text
#         print(details, '-'*80)
    mylist.append(mydict)

# %%
mylist2=[{k.replace('\n','').replace('\t',''): v.replace('\n','').replace('\t','') for k,v in x.items()} for x in mylist]

# %%
options_df=pd.DataFrame(mylist2)

# %%
pd.merge(edh_df,options_df,left_index=True,right_index=True)
# Out:
#     Stock #                 Original Price                     Sales Price  \
# 0    R20899              $38,240                         $32,578
# 1    R20910              $39,395                         $34,298
# 2    R20964              $35,145                         $32,452
# 3    R20979              $47,991                         $41,995
# 4    R20811              $45,175                         $36,892
# 5    R20990              $39,095                         $34,332
# 6    R20988              $45,095                         $38,079
# 7    R20986              $79,520                         $67,922
# 8    R20987              $61,650                         $51,983
# 9    R20992              $33,995                         $26,992
# 10   R21005              $69,995                         $64,322
# 11   R21011              $54,991                         $49,222
# 12   R21024              $35,995                         $31,422
# 13   R21031              $32,995                         $28,992
# 14   R21032              $72,995                         $64,992
# 15   R21035              $49,995                         $45,922
# 16   R21037              $53,945                         $49,622
# 17   R21040              $23,995                         $21,982
# 18   R21038              $44,995                         $41,992
# 19   R21041              $46,575                         $41,995
#
#                  Vin #                                       Vehicle Name  \
# 0    WDDSJ4EBXKN742067  Pre-Owned 2019 Mercedes-Benz CLA 250 Front Whe...
# 1    WDCTG4GB9KJ551848   Pre-Owned 2019 Mercedes-Benz GLA 250 AWD 4MATIC®
# 2    WDDSJ4EB5KN708246  Pre-Owned 2019 Mercedes-Benz CLA 250 Front Whe...
# 3    WDC0G4KB8JV070443   Pre-Owned 2018 Mercedes-Benz GLC 300 AWD 4MATIC®
# 4    55SWF4JB3JU280062  Pre-Owned 2018 Mercedes-Benz C 300 Rear Wheel ...
# 5    WDDSJ4EB5KN714435  Pre-Owned 2019 Mercedes-Benz CLA 250 Front Whe...
# 6    55SWF8DB9KU286789  Pre-Owned 2019 Mercedes-Benz C 300 Rear Wheel ...
# 7    4JGDF6EE3KB205371   Pre-Owned 2019 Mercedes-Benz GLS 450 AWD 4MATIC®
# 8    4JGDA5GB7KB212111   Pre-Owned 2019 Mercedes-Benz GLE 400 AWD 4MATIC®
# 9    55SWF4HB3GU152726  Certified Pre-Owned 2016 Mercedes-Benz C 350 R...
# 10   WBA6D6C54GGK18191  Pre-Owned 2016 BMW 6 Series ALPINA B6 G/CP AWD...
# 11   WDDLJ7DB3GA164982  Certified Pre-Owned 2016 Mercedes-Benz CLS 550...
# 12   JTHBW1GG7H2138004                Pre-Owned 2017 Lexus ES ES 300h FWD
# 13   WDDSJ4EB7JN536137  Certified Pre-Owned 2018 Mercedes-Benz CLA 250...
# 14   5UXCR6C52KLL05903            Pre-Owned 2019 BMW X5 xDrive40i AWD AWD
# 15   5J8YD4H89JL024615     Pre-Owned 2018 Acura MDX w/Advance Pkg AWD AWD
# 16   WDC0G5EB7JF406286  Certified Pre-Owned 2018 Mercedes-Benz GLC 350...
# 17   WDDSJ4EB1EN120932  Certified Pre-Owned 2014 Mercedes-Benz CLA 250...
# 18   55SWF6EB9GU120542  Certified Pre-Owned 2016 Mercedes-Benz C 450 A...
# 19   55SWF8DBXKU295565  Pre-Owned 2019 Mercedes-Benz C 300 Rear Wheel ...
#
#             Drivetrain                                             Engine  \
# 0    Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 1          AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 2    Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3          AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 4     Rear Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 5    Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 6     Rear Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 7          AWD 4MATIC®          Twin Turbo Premium Unleaded V-6 3.0 L/183
# 8          AWD 4MATIC®          Twin Turbo Premium Unleaded V-6 3.0 L/183
# 9     Rear Wheel Drive       Intercooled Turbo Gas/Electric I-4 2.0 L/121
# 10                 AWD          Twin Turbo Premium Unleaded V-8 4.4 L/268
# 11    Rear Wheel Drive          Twin Turbo Premium Unleaded V-8 4.7 L/285
# 12                 FWD                         Gas/Electric I-4 2.5 L/152
# 13   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 14                 AWD   Intercooled Turbo Premium Unleaded I-6 3.0 L/183
# 15                 AWD                     Premium Unleaded V-6 3.5 L/212
# 16         AWD 4MATIC®       Intercooled Turbo Gas/Electric I-4 2.0 L/121
# 17   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 18         AWD 4MATIC®          Twin Turbo Premium Unleaded V-6 3.0 L/183
# 19    Rear Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                            Exterior  \
# 0                     Mountain Grey
# 1                       Polar White
# 2                       Night Black
# 3           Brilliant Blue Metallic
# 4                             Black
# 5                       Night Black
# 6            Emerald Green Metallic
# 7                       Polar White
# 8                             Black
# 9                             Black
# 10                            BLACK
# 11           Selenite Grey Metallic
# 12                             Gray
# 13                     Cirrus White
# 14                            BLACK
# 15                             Gray
# 16           Selenite Grey Metallic
# 17                    Mountain Grey
# 18   designo Diamond White Metallic
# 19                      Polar White
#
#                                                   HWY  \
# 0    37 MPG                                       ...
# 1    31 MPG                                       ...
# 2    37 MPG                                       ...
# 3    28 MPG                                       ...
# 4    33 MPG                                       ...
# 5    37 MPG                                       ...
# 6    34 MPG                                       ...
# 7    22 MPG                                       ...
# 8    23 MPG                                       ...
# 9                                                 NaN
# 10   24 MPG                                       ...
# 11   26 MPG                                       ...
# 12   39 MPG                                       ...
# 13   37 MPG                                       ...
# 14   26 MPG                                       ...
# 15   26 MPG                                       ...
# 16                                                NaN
# 17   38 MPG                                       ...
# 18   29 MPG                                       ...
# 19   34 MPG                                       ...
#
#                                       Interior  Mileage  \
# 0                                 Black MB-Tex    9,188
# 1                                 Black MB-Tex    5,814
# 2                                 Black MB-Tex    5,798
# 3                                 Black MB-Tex    4,985
# 4                            Silk Beige MB-Tex    6,866
# 5                                 Black MB-Tex    5,006
# 6                            Silk Beige MB-Tex    7,405
# 7                                 Black MB-Tex    7,881
# 8                                 Black MB-Tex    9,334
# 9                                 Black MB-Tex   20,070
# 10                                       Brown   29,928
# 11   Black Leather w/ white contrast stitching   40,272
# 12                                       Black   32,578
# 13                                Black MB-Tex    8,964
# 14                                       Brown    2,672
# 15                                       Black   13,122
# 16                                Black MB-Tex   31,299
# 17                    Black MB-Tex w/ DINAMICA   53,671
# 18                       Cranberry Red Leather   31,588
# 19                                Black MB-Tex    8,395
#
#                               Trans
# 0    7-Speed Auto-Shift Manual w/OD
# 1    7-Speed Auto-Shift Manual w/OD
# 2    7-Speed Auto-Shift Manual w/OD
# 3            9-Speed Automatic w/OD
# 4            9-Speed Automatic w/OD
# 5    7-Speed Auto-Shift Manual w/OD
# 6            9-Speed Automatic w/OD
# 7            9-Speed Automatic w/OD
# 8            9-Speed Automatic w/OD
# 9            7-Speed Automatic w/OD
# 10           8-Speed Automatic w/OD
# 11           9-Speed Automatic w/OD
# 12                 1-Speed CVT w/OD
# 13   7-Speed Auto-Shift Manual w/OD
# 14           8-Speed Automatic w/OD
# 15           9-Speed Automatic w/OD
# 16           7-Speed Automatic w/OD
# 17   7-Speed Auto-Shift Manual w/OD
# 18           7-Speed Automatic w/OD
# 19           9-Speed Automatic w/OD

# %%
import codecs
f=codecs.open("EDH_website_1.html", 'r','utf-8').read()
# print (f.read())

# %%
edh_soup_1 = bs(f,'html.parser')

# %%
mylist=[]
options=edh_soup_1.find_all('div',class_='options')
for car in options:
#     car_sublist = []
    mydict={}
    for li in car.find_all('li'):
        
        mydict[li.text.split(':')[0]]=li.text.split(':')[1]
        details=car.text
#         print(details, '-'*80)
    mylist.append(mydict)

# %%
mylist2=[{k.replace('\n','').replace('\t',''): v.replace('\n','').replace('\t','') for k,v in x.items()} for x in mylist]

# %%
options_df=pd.DataFrame(mylist2)
options_df.head()
# Out:
#            Drivetrain                                             Engine  \
# 0   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 1         AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 2   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3         AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 4    Rear Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                    Exterior  \
# 0             Mountain Grey
# 1               Polar White
# 2               Night Black
# 3   Brilliant Blue Metallic
# 4                     Black
#
#                                                  HWY            Interior  \
# 0   37 MPG                                       ...        Black MB-Tex
# 1   31 MPG                                       ...        Black MB-Tex
# 2   37 MPG                                       ...        Black MB-Tex
# 3   28 MPG                                       ...        Black MB-Tex
# 4   33 MPG                                       ...   Silk Beige MB-Tex
#
#   Mileage                            Trans
# 0   9,188   7-Speed Auto-Shift Manual w/OD
# 1   5,814   7-Speed Auto-Shift Manual w/OD
# 2   5,798   7-Speed Auto-Shift Manual w/OD
# 3   4,985           9-Speed Automatic w/OD
# 4   6,866           9-Speed Automatic w/OD

# %%
cars=edh_soup_1.find_all('div',class_='vehicle-overview')

# %%
stocks=[]
prices=[]
vins=[]
sale_prices=[]
titles=[]
years=[]

for car in cars:
    if car.find('div',class_='price-block our-price ') is not None:
        stock=car.find('span',class_='stock-label').text
        stock=stock.split(':')[1]
        stocks.append(stock)

        vin=car.span.text
        vin=vin.split(':')[1]
        vins.append(vin)
        if car.find('div',class_='price-block original') is not None:
            price=car.find('div',class_='price-block original').find('span',class_='price').text
            prices.append(price)
            prices=[x.replace('\n','').replace('\t','') for x in prices]

        sale_price=car.find('div',class_='price-block our-price ').find('span',class_='price').text
        sale_prices.append(sale_price)
        sale_prices=[x.replace('\n','').replace('\t','') for x in sale_prices]
        
        year=car.find('a').text
        if year.split(" ")[0] == "Certified":
            year=year.split(" ")[2]
            years.append(year)
        else:
            year=year.split(" ")[1]
            years.append(year)
        
        title=car.find('a').text
        if title.split(' ',2)[0]=='Pre-Owned':
            title=title.split(' ',2)[2]
            titles.append(title)
        else:
            title=title.split(' ',3)[3]
            titles.append(title)

# %%
edh_df_1=pd.DataFrame({'Stock #': stocks,
'Original Price': prices,
'Sales Price': sale_prices,
'Vin #': vins,
'Vehicle Name':titles,
'Year':years
})
edh_df_1
# Out:
#     Stock #                 Original Price                     Sales Price  \
# 0    R20899              $38,240                         $32,578
# 1    R20910              $39,395                         $34,298
# 2    R20964              $35,145                         $32,452
# 3    R20979              $47,991                         $39,995
# 4    R20811              $45,175                         $36,892
# 5    R20987              $61,650                         $51,983
# 6    R20990              $39,095                         $34,332
# 7    R20988              $45,095                         $38,079
# 8    R20986              $79,520                         $67,922
# 9    R20992              $33,995                         $26,992
# 10   R21005              $69,995                         $64,322
# 11   R21011              $54,991                         $49,222
# 12   R21024              $35,995                         $31,422
# 13   R21031              $32,995                         $28,992
# 14   R21035              $49,995                         $45,922
# 15   R21037              $53,945                         $49,622
# 16   R21040              $23,995                         $21,982
# 17   R21041              $46,575                         $41,995
# 18   R21042              $47,385                         $41,286
# 19   R21048              $27,792                         $26,312
#
#                  Vin #                             Vehicle Name  Year
# 0    WDDSJ4EBXKN742067  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 1    WDCTG4GB9KJ551848        Mercedes-Benz GLA 250 AWD 4MATIC®  2019
# 2    WDDSJ4EB5KN708246  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 3    WDC0G4KB8JV070443        Mercedes-Benz GLC 300 AWD 4MATIC®  2018
# 4    55SWF4JB3JU280062     Mercedes-Benz C 300 Rear Wheel Drive  2018
# 5    4JGDA5GB7KB212111        Mercedes-Benz GLE 400 AWD 4MATIC®  2019
# 6    WDDSJ4EB5KN714435  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 7    55SWF8DB9KU286789     Mercedes-Benz C 300 Rear Wheel Drive  2019
# 8    4JGDF6EE3KB205371        Mercedes-Benz GLS 450 AWD 4MATIC®  2019
# 9    55SWF4HB3GU152726     Mercedes-Benz C 350 Rear Wheel Drive  2016
# 10   WBA6D6C54GGK18191      BMW 6 Series ALPINA B6 G/CP AWD AWD  2016
# 11   WDDLJ7DB3GA164982   Mercedes-Benz CLS 550 Rear Wheel Drive  2016
# 12   JTHBW1GG7H2138004                     Lexus ES ES 300h FWD  2017
# 13   WDDSJ4EB7JN536137  Mercedes-Benz CLA 250 Front Wheel Drive  2018
# 14   5J8YD4H89JL024615          Acura MDX w/Advance Pkg AWD AWD  2018
# 15   WDC0G5EB7JF406286        Mercedes-Benz GLC 350 AWD 4MATIC®  2018
# 16   WDDSJ4EB1EN120932  Mercedes-Benz CLA 250 Front Wheel Drive  2014
# 17   55SWF8DBXKU295565     Mercedes-Benz C 300 Rear Wheel Drive  2019
# 18   WDC0G4JB3K1001119   Mercedes-Benz GLC 300 Rear Wheel Drive  2019
# 19   WDCGG5HB0FG424074   Mercedes-Benz GLK 350 Rear Wheel Drive  2015

# %%
edh_df_1=pd.merge(edh_df_1,options_df,left_index=True,right_index=True)
edh_df_1.head()
# Out:
#    Stock #                 Original Price                     Sales Price  \
# 0   R20899              $38,240                         $32,578
# 1   R20910              $39,395                         $34,298
# 2   R20964              $35,145                         $32,452
# 3   R20979              $47,991                         $39,995
# 4   R20811              $45,175                         $36,892
#
#                 Vin #                             Vehicle Name  Year  \
# 0   WDDSJ4EBXKN742067  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 1   WDCTG4GB9KJ551848        Mercedes-Benz GLA 250 AWD 4MATIC®  2019
# 2   WDDSJ4EB5KN708246  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 3   WDC0G4KB8JV070443        Mercedes-Benz GLC 300 AWD 4MATIC®  2018
# 4   55SWF4JB3JU280062     Mercedes-Benz C 300 Rear Wheel Drive  2018
#
#            Drivetrain                                             Engine  \
# 0   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 1         AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 2   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3         AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 4    Rear Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                    Exterior  \
# 0             Mountain Grey
# 1               Polar White
# 2               Night Black
# 3   Brilliant Blue Metallic
# 4                     Black
#
#                                                  HWY            Interior  \
# 0   37 MPG                                       ...        Black MB-Tex
# 1   31 MPG                                       ...        Black MB-Tex
# 2   37 MPG                                       ...        Black MB-Tex
# 3   28 MPG                                       ...        Black MB-Tex
# 4   33 MPG                                       ...   Silk Beige MB-Tex
#
#   Mileage                            Trans
# 0   9,188   7-Speed Auto-Shift Manual w/OD
# 1   5,814   7-Speed Auto-Shift Manual w/OD
# 2   5,798   7-Speed Auto-Shift Manual w/OD
# 3   4,985           9-Speed Automatic w/OD
# 4   6,866           9-Speed Automatic w/OD

# %%
import codecs
f=codecs.open("EDH_website_2.html", 'r','utf-8').read()
# print (f.read())

# %%
edh_soup_2 = bs(f,'html.parser')

# %%
mylist=[]
options=edh_soup_2.find_all('div',class_='options')
for car in options:
#     car_sublist = []
    mydict={}
    for li in car.find_all('li'):
        
        mydict[li.text.split(':')[0]]=li.text.split(':')[1]
        details=car.text
#         print(details, '-'*80)
    mylist.append(mydict)

# %%
mylist2=[{k.replace('\n','').replace('\t',''): v.replace('\n','').replace('\t','') for k,v in x.items()} for x in mylist]

# %%
options_df=pd.DataFrame(mylist2)

# %%
stocks=[]
prices=[]
vins=[]
sale_prices=[]
titles=[]
years=[]

for car in cars:
    if car.find('div',class_='price-block our-price ') is not None:
        stock=car.find('span',class_='stock-label').text
        stock=stock.split(':')[1]
        stocks.append(stock)

        vin=car.span.text
        vin=vin.split(':')[1]
        vins.append(vin)
        if car.find('div',class_='price-block original') is not None:
            price=car.find('div',class_='price-block original').find('span',class_='price').text
            prices.append(price)
            prices=[x.replace('\n','').replace('\t','') for x in prices]

        sale_price=car.find('div',class_='price-block our-price ').find('span',class_='price').text
        sale_prices.append(sale_price)
        sale_prices=[x.replace('\n','').replace('\t','') for x in sale_prices]
        
        year=car.find('a').text
        if year.split(" ")[0] == "Certified":
            year=year.split(" ")[2]
            years.append(year)
        else:
            year=year.split(" ")[1]
            years.append(year)
        
        title=car.find('a').text
        if title.split(' ',2)[0]=='Pre-Owned':
            title=title.split(' ',2)[2]
            titles.append(title)
        else:
            title=title.split(' ',3)[3]
            titles.append(title)

# %%
edh_df_2=pd.DataFrame({'Stock #': stocks,
'Original Price': prices,
'Sales Price': sale_prices,
'Vin #': vins,
'Vehicle Name':titles,
'Year': years
})
edh_df_2.head()
# Out:
#    Stock #                 Original Price                     Sales Price  \
# 0   R20899              $38,240                         $32,578
# 1   R20910              $39,395                         $34,298
# 2   R20964              $35,145                         $32,452
# 3   R20979              $47,991                         $39,995
# 4   R20811              $45,175                         $36,892
#
#                 Vin #                             Vehicle Name  Year
# 0   WDDSJ4EBXKN742067  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 1   WDCTG4GB9KJ551848        Mercedes-Benz GLA 250 AWD 4MATIC®  2019
# 2   WDDSJ4EB5KN708246  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 3   WDC0G4KB8JV070443        Mercedes-Benz GLC 300 AWD 4MATIC®  2018
# 4   55SWF4JB3JU280062     Mercedes-Benz C 300 Rear Wheel Drive  2018

# %%
edh_df_2=pd.merge(edh_df_2,options_df,left_index=True,right_index=True)
edh_df_2.head()
# Out:
#    Stock #                 Original Price                     Sales Price  \
# 0   R20899              $38,240                         $32,578
# 1   R20910              $39,395                         $34,298
# 2   R20964              $35,145                         $32,452
# 3   R20979              $47,991                         $39,995
# 4   R20811              $45,175                         $36,892
#
#                 Vin #                             Vehicle Name  Year  \
# 0   WDDSJ4EBXKN742067  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 1   WDCTG4GB9KJ551848        Mercedes-Benz GLA 250 AWD 4MATIC®  2019
# 2   WDDSJ4EB5KN708246  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 3   WDC0G4KB8JV070443        Mercedes-Benz GLC 300 AWD 4MATIC®  2018
# 4   55SWF4JB3JU280062     Mercedes-Benz C 300 Rear Wheel Drive  2018
#
#            Drivetrain                                             Engine  \
# 0         AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 1    Rear Wheel Drive                     Premium Unleaded V-6 3.5 L/213
# 2    Rear Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3    Rear Wheel Drive          Twin Turbo Premium Unleaded V-8 4.7 L/285
# 4   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                           Exterior  \
# 0                      Night Black
# 1                   Iridium Silver
# 2              Lunar Blue Metallic
# 3   designo Diamond White Metallic
# 4                    Mountain Grey
#
#                                                  HWY  \
# 0   32 MPG                                       ...
# 1   29 MPG                                       ...
# 2   34 MPG                                       ...
# 3   26 MPG                                       ...
# 4   37 MPG                                       ...
#
#                             Interior  Mileage                            Trans
# 0                       Black MB-Tex   23,463   7-Speed Auto-Shift Manual w/OD
# 1                       Black MB-Tex   36,255           7-Speed Automatic w/OD
# 2   Luxury Silk BeigeEspresso MB-Tex   13,481           7-Speed Automatic w/OD
# 3       Saddle Brown / Black Leather   35,947           9-Speed Automatic w/OD
# 4                Crystal Grey MB-Tex    8,760   7-Speed Auto-Shift Manual w/OD

# %%
import codecs
f=codecs.open("EDH_website_3.html", 'r','utf-8').read()
# print (f.read())

# %%
edh_soup_3 = bs(f,'html.parser')

# %%
mylist=[]
options=edh_soup_3.find_all('div',class_='options')
for car in options:
#     car_sublist = []
    mydict={}
    for li in car.find_all('li'):
        
        mydict[li.text.split(':')[0]]=li.text.split(':')[1]
        details=car.text
#         print(details, '-'*80)
    mylist.append(mydict)

# %%
mylist2=[{k.replace('\n','').replace('\t',''): v.replace('\n','').replace('\t','') for k,v in x.items()} for x in mylist]

# %%
options_df=pd.DataFrame(mylist2)

# %%
cars=edh_soup_3.find_all('div',class_='vehicle-overview')

# %%
stocks=[]
prices=[]
vins=[]
sale_prices=[]
titles=[]
years=[]

for car in cars:
    if car.find('div',class_='price-block our-price ') is not None:
        stock=car.find('span',class_='stock-label').text
        stock=stock.split(':')[1]
        stocks.append(stock)

        vin=car.span.text
        vin=vin.split(':')[1]
        vins.append(vin)
        if car.find('div',class_='price-block original') is not None:
            price=car.find('div',class_='price-block original').find('span',class_='price').text
            prices.append(price)
            prices=[x.replace('\n','').replace('\t','') for x in prices]

        sale_price=car.find('div',class_='price-block our-price ').find('span',class_='price').text
        sale_prices.append(sale_price)
        sale_prices=[x.replace('\n','').replace('\t','') for x in sale_prices]
        
        year=car.find('a').text
        if year.split(" ")[0] == "Certified":
            year=year.split(" ")[2]
            years.append(year)
        else:
            year=year.split(" ")[1]
            years.append(year)
        
        title=car.find('a').text
        if title.split(' ',2)[0]=='Pre-Owned':
            title=title.split(' ',2)[2]
            titles.append(title)
        else:
            title=title.split(' ',3)[3]
            titles.append(title)

# %%
edh_df_3=pd.DataFrame({'Stock #': stocks,
'Sales Price': sale_prices,
'Vin #': vins,
'Vehicle Name':titles,
'Year': years
})
edh_df_3
# Out:
#    Stock #                     Sales Price               Vin #  \
# 0   R21124               $17,995             WDCGG8HB6CF747189
# 1   R21122               $32,995             WDDSJ4EB4KN699670
# 2   R21123               $22,995             WDDSJ4EB6EN033141
# 3   R21128               $31,992             55SWF4KB9GU149256
# 4   R21112               $38,952             WDC0G4KB0HF154468
# 5   R21127         Please Call for Price     WDC0G5EB7KF509483
# 6   R21125               $31,992             55SWF4JB6GU122940
# 7   R21126               $21,922             WBA3A9G52DNP37318
#
#                               Vehicle Name  Year
# 0        Mercedes-Benz GLK 350 AWD 4MATIC®  2012
# 1  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 2                Mercedes-Benz CLA 250 FWD  2014
# 3        Mercedes-Benz C 300W4 AWD 4MATIC®  2016
# 4        Mercedes-Benz GLC 300 AWD 4MATIC®  2017
# 5       Mercedes-Benz GLC 350e AWD 4MATIC®  2019
# 6                 Mercedes-Benz C 300W RWD  2016
# 7                    BMW 3 Series 335i RWD  2013

# %%
edh_df_3=pd.merge(edh_df_3,options_df,left_index=True,right_index=True)
edh_df_3.head()
# Out:
#    Stock #                     Sales Price               Vin #  \
# 0   R21124               $17,995             WDCGG8HB6CF747189
# 1   R21122               $32,995             WDDSJ4EB4KN699670
# 2   R21123               $22,995             WDDSJ4EB6EN033141
# 3   R21128               $31,992             55SWF4KB9GU149256
# 4   R21112               $38,952             WDC0G4KB0HF154468
#
#                               Vehicle Name  Year          Drivetrain  \
# 0        Mercedes-Benz GLK 350 AWD 4MATIC®  2012          AWD 4MATIC
# 1  Mercedes-Benz CLA 250 Front Wheel Drive  2019   Front Wheel Drive
# 2                Mercedes-Benz CLA 250 FWD  2014                 FWD
# 3        Mercedes-Benz C 300W4 AWD 4MATIC®  2016          AWD 4MATIC
# 4        Mercedes-Benz GLC 300 AWD 4MATIC®  2017          AWD 4MATIC
#
#                                               Engine  \
# 0                                    Gas V6 3.5L/213
# 1   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 2   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 4   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                           Exterior  \
# 0        Palladium Silver Metallic
# 1                    Mountain Grey
# 2           Universe Blue Metallic
# 3                      Polar White
# 4   designo Diamond White Metallic
#
#                                                  HWY          Interior  \
# 0   21 MPG                                       ...             Black
# 1   37 MPG                                       ...      Black MB-Tex
# 2   38 MPG                                       ...               Ash
# 3   31 MPG                                       ...   SILK BEIGE MB T
# 4   28 MPG                                       ...             Black
#
#    Mileage                            Trans
# 0   82,309                7-Speed Automatic
# 1    8,365   7-Speed Auto-Shift Manual w/OD
# 2   67,940   7-Speed Auto-Shift Manual w/OD
# 3   32,389           7-Speed Automatic w/OD
# 4   38,059           9-Speed Automatic w/OD

# %%
import codecs
f=codecs.open("EDH_website_4.html", 'r','utf-8').read()
# print (f.read())

# %%
edh_soup_4 = bs(f,'html.parser')

# %%
mylist=[]
options=edh_soup_4.find_all('div',class_='options')
for car in options:
#     car_sublist = []
    mydict={}
    for li in car.find_all('li'):
        
        mydict[li.text.split(':')[0]]=li.text.split(':')[1]
        details=car.text
#         print(details, '-'*80)
    mylist.append(mydict)

# %%
mylist2=[{k.replace('\n','').replace('\t',''): v.replace('\n','').replace('\t','') for k,v in x.items()} for x in mylist]

# %%
options_df=pd.DataFrame(mylist2)
options_df.head()
# Out:
#            Drivetrain                                             Engine  \
# 0          AWD 4MATIC                                    Gas V6 3.5L/213
# 1   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 2                 FWD   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3          AWD 4MATIC   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 4          AWD 4MATIC   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                           Exterior  \
# 0        Palladium Silver Metallic
# 1                    Mountain Grey
# 2           Universe Blue Metallic
# 3                      Polar White
# 4   designo Diamond White Metallic
#
#                                                  HWY          Interior  \
# 0   21 MPG                                       ...             Black
# 1   37 MPG                                       ...      Black MB-Tex
# 2   38 MPG                                       ...               Ash
# 3   31 MPG                                       ...   SILK BEIGE MB T
# 4   28 MPG                                       ...             Black
#
#    Mileage                            Trans
# 0   82,309                7-Speed Automatic
# 1    8,365   7-Speed Auto-Shift Manual w/OD
# 2   67,940   7-Speed Auto-Shift Manual w/OD
# 3   32,389           7-Speed Automatic w/OD
# 4   38,059           9-Speed Automatic w/OD

# %%
first_car=edh_soup_4.find('div',class_='vehicle-overview')
first_car.find('div',class_='price-block our-price ').find('span',class_='price').text
# Out:
# '\n             $17,995          '

# %%
stocks=[]
prices=[]
vins=[]
sale_prices=[]
titles=[]
years=[]

for car in cars:
    if car.find('div',class_='price-block our-price ') is not None:
        stock=car.find('span',class_='stock-label').text
        stock=stock.split(':')[1]
        stocks.append(stock)

        vin=car.span.text
        vin=vin.split(':')[1]
        vins.append(vin)
        if car.find('div',class_='price-block original') is not None:
            price=car.find('div',class_='price-block original').find('span',class_='price').text
            prices.append(price)
            prices=[x.replace('\n','').replace('\t','') for x in prices]

        sale_price=car.find('div',class_='price-block our-price ').find('span',class_='price').text
        sale_prices.append(sale_price)
        sale_prices=[x.replace('\n','').replace('\t','') for x in sale_prices]
        
        year=car.find('a').text
        if year.split(" ")[0] == "Certified":
            year=year.split(" ")[2]
            years.append(year)
        else:
            year=year.split(" ")[1]
            years.append(year)
        
        title=car.find('a').text
        if title.split(' ',2)[0]=='Pre-Owned':
            title=title.split(' ',2)[2]
            titles.append(title)
        else:
            title=title.split(' ',3)[3]
            titles.append(title)

# %%
edh_df_4=pd.DataFrame({'Stock #': stocks,
'Sales Price': sale_prices,
'Vin #': vins,
'Vehicle Name':titles,
'Year': years
})
edh_df_4
# Out:
#    Stock #                     Sales Price               Vin #  \
# 0   R21124               $17,995             WDCGG8HB6CF747189
# 1   R21122               $32,995             WDDSJ4EB4KN699670
# 2   R21123               $22,995             WDDSJ4EB6EN033141
# 3   R21128               $31,992             55SWF4KB9GU149256
# 4   R21112               $38,952             WDC0G4KB0HF154468
# 5   R21127         Please Call for Price     WDC0G5EB7KF509483
# 6   R21125               $31,992             55SWF4JB6GU122940
# 7   R21126               $21,922             WBA3A9G52DNP37318
#
#                               Vehicle Name  Year
# 0        Mercedes-Benz GLK 350 AWD 4MATIC®  2012
# 1  Mercedes-Benz CLA 250 Front Wheel Drive  2019
# 2                Mercedes-Benz CLA 250 FWD  2014
# 3        Mercedes-Benz C 300W4 AWD 4MATIC®  2016
# 4        Mercedes-Benz GLC 300 AWD 4MATIC®  2017
# 5       Mercedes-Benz GLC 350e AWD 4MATIC®  2019
# 6                 Mercedes-Benz C 300W RWD  2016
# 7                    BMW 3 Series 335i RWD  2013

# %%
edh_df_4=pd.merge(edh_df_4,options_df,left_index=True,right_index=True)
edh_df_4.head()
# Out:
#    Stock #                     Sales Price               Vin #  \
# 0   R21124               $17,995             WDCGG8HB6CF747189
# 1   R21122               $32,995             WDDSJ4EB4KN699670
# 2   R21123               $22,995             WDDSJ4EB6EN033141
# 3   R21128               $31,992             55SWF4KB9GU149256
# 4   R21112               $38,952             WDC0G4KB0HF154468
#
#                               Vehicle Name  Year          Drivetrain  \
# 0        Mercedes-Benz GLK 350 AWD 4MATIC®  2012          AWD 4MATIC
# 1  Mercedes-Benz CLA 250 Front Wheel Drive  2019   Front Wheel Drive
# 2                Mercedes-Benz CLA 250 FWD  2014                 FWD
# 3        Mercedes-Benz C 300W4 AWD 4MATIC®  2016          AWD 4MATIC
# 4        Mercedes-Benz GLC 300 AWD 4MATIC®  2017          AWD 4MATIC
#
#                                               Engine  \
# 0                                    Gas V6 3.5L/213
# 1   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 2   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 4   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                           Exterior  \
# 0        Palladium Silver Metallic
# 1                    Mountain Grey
# 2           Universe Blue Metallic
# 3                      Polar White
# 4   designo Diamond White Metallic
#
#                                                  HWY          Interior  \
# 0   21 MPG                                       ...             Black
# 1   37 MPG                                       ...      Black MB-Tex
# 2   38 MPG                                       ...               Ash
# 3   31 MPG                                       ...   SILK BEIGE MB T
# 4   28 MPG                                       ...             Black
#
#    Mileage                            Trans
# 0   82,309                7-Speed Automatic
# 1    8,365   7-Speed Auto-Shift Manual w/OD
# 2   67,940   7-Speed Auto-Shift Manual w/OD
# 3   32,389           7-Speed Automatic w/OD
# 4   38,059           9-Speed Automatic w/OD

# %%
edh_df=pd.concat([edh_df_1,edh_df_2,edh_df_3,edh_df_4])
edh_df.head()
# Out:
# C:\conda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#            Drivetrain                                             Engine  \
# 0   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 1         AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 2   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3         AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 4    Rear Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                    Exterior  \
# 0             Mountain Grey
# 1               Polar White
# 2               Night Black
# 3   Brilliant Blue Metallic
# 4                     Black
#
#                                                  HWY            Interior  \
# 0   37 MPG                                       ...        Black MB-Tex
# 1   31 MPG                                       ...        Black MB-Tex
# 2   37 MPG                                       ...        Black MB-Tex
# 3   28 MPG                                       ...        Black MB-Tex
# 4   33 MPG                                       ...   Silk Beige MB-Tex
#
#   Mileage                 Original Price                     Sales Price  \
# 0   9,188              $38,240                         $32,578
# 1   5,814              $39,395                         $34,298
# 2   5,798              $35,145                         $32,452
# 3   4,985              $47,991                         $39,995
# 4   6,866              $45,175                         $36,892
#
#    Stock #                            Trans  \
# 0   R20899   7-Speed Auto-Shift Manual w/OD
# 1   R20910   7-Speed Auto-Shift Manual w/OD
# 2   R20964   7-Speed Auto-Shift Manual w/OD
# 3   R20979           9-Speed Automatic w/OD
# 4   R20811           9-Speed Automatic w/OD
#
#                               Vehicle Name               Vin #  Year
# 0  Mercedes-Benz CLA 250 Front Wheel Drive   WDDSJ4EBXKN742067  2019
# 1        Mercedes-Benz GLA 250 AWD 4MATIC®   WDCTG4GB9KJ551848  2019
# 2  Mercedes-Benz CLA 250 Front Wheel Drive   WDDSJ4EB5KN708246  2019
# 3        Mercedes-Benz GLC 300 AWD 4MATIC®   WDC0G4KB8JV070443  2018
# 4     Mercedes-Benz C 300 Rear Wheel Drive   55SWF4JB3JU280062  2018

# %%
location=edh_soup_1.find('h1').text
location=location.split('in ',1)[1]
edh_df['Location']=location

# %%
edh_df['Location']=location

# %%
edh_df.head()
# Out:
#            Drivetrain                                             Engine  \
# 0   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 1         AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 2   Front Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 3         AWD 4MATIC®   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
# 4    Rear Wheel Drive   Intercooled Turbo Premium Unleaded I-4 2.0 L/121
#
#                    Exterior  \
# 0             Mountain Grey
# 1               Polar White
# 2               Night Black
# 3   Brilliant Blue Metallic
# 4                     Black
#
#                                                  HWY            Interior  \
# 0   37 MPG                                       ...        Black MB-Tex
# 1   31 MPG                                       ...        Black MB-Tex
# 2   37 MPG                                       ...        Black MB-Tex
# 3   28 MPG                                       ...        Black MB-Tex
# 4   33 MPG                                       ...   Silk Beige MB-Tex
#
#   Mileage                 Original Price                     Sales Price  \
# 0   9,188              $38,240                         $32,578
# 1   5,814              $39,395                         $34,298
# 2   5,798              $35,145                         $32,452
# 3   4,985              $47,991                         $39,995
# 4   6,866              $45,175                         $36,892
#
#    Stock #                            Trans  \
# 0   R20899   7-Speed Auto-Shift Manual w/OD
# 1   R20910   7-Speed Auto-Shift Manual w/OD
# 2   R20964   7-Speed Auto-Shift Manual w/OD
# 3   R20979           9-Speed Automatic w/OD
# 4   R20811           9-Speed Automatic w/OD
#
#                               Vehicle Name               Vin #  Year  \
# 0  Mercedes-Benz CLA 250 Front Wheel Drive   WDDSJ4EBXKN742067  2019
# 1        Mercedes-Benz GLA 250 AWD 4MATIC®   WDCTG4GB9KJ551848  2019
# 2  Mercedes-Benz CLA 250 Front Wheel Drive   WDDSJ4EB5KN708246  2019
# 3        Mercedes-Benz GLC 300 AWD 4MATIC®   WDC0G4KB8JV070443  2018
# 4     Mercedes-Benz C 300 Rear Wheel Drive   55SWF4JB3JU280062  2018
#
#                       Location
# 0  El Dorado Hills, CA
# 1  El Dorado Hills, CA
# 2  El Dorado Hills, CA
# 3  El Dorado Hills, CA
# 4  El Dorado Hills, CA

# %%
edh_df.to_csv('edh_df.csv', sep = ',')
